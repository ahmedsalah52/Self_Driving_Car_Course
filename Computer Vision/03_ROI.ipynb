# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('Files/carkyo.jpg')

# %%
plt.imshow(img[:,:,::-1]);

# %%
roi = img[0:150, 0:150]
plt.imshow(roi[:,:,::-1]);

# %%
copy = img.copy()
copy[500:650, 700:850] = roi

# %%
plt.imshow(copy[:,:,::-1]);

# %%
copy [250:300, 250:500] = [255,0,0]
plt.imshow(copy[:,:,::-1]);

# %% [markdown]
# # Arethmatic

# %%
logo = cv2.imread('../Files/tekomoro.png')

# %%
plt.imshow(logo[:,:,::-1]);

# %%
logo.shape
# Out:
# (287, 1780, 3)

# %%
img.shape
# Out:
# (768, 1365, 3)

# %%
logo = cv2.resize(logo, (500, 100))
plt.imshow(logo[:,:,::-1]);

# %%
logo.shape
# Out:
# (100, 500, 3)

# %%
copy [500:600, 500:1000] = logo
plt.imshow(copy[:,:,::-1])

# %%
out = cv2.addWeighted(img, 1, logo, 0.1, 0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-29-8d7ee1e20bda> in <module>
# ----> 1 out = cv2.addWeighted(img, 1, logo, 0.1, 0)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-i1s8y2i1\opencv\modules\core\src\arithm.cpp:669: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
sub = img[0:100, 0:500]
plt.imshow(sub[:,:,::-1]);

# %%
out = cv2.addWeighted(sub, 1, logo, 1, 0)
plt.imshow(out[:,:,::-1]);

# %%
copy = img.copy()
copy[0:100, 0:500] = out
plt.imshow(copy[:,:,::-1]);

# %%
out = img.copy()

# %%
out[0:100, 0:500] = cv2.addWeighted(img[0:100, 0:500], 1, logo, 1, 0)
plt.imshow(out[:,:,::-1]);

# %%
rows, cols, chs = logo.shape
plt.imshow(img[0:rows, 0:cols, ::-1]);
roi = img[0:rows, 0:cols];

# %%
gray = cv2.cvtColor(logo, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray');

# %%
ret, mask = cv2.threshold(gray, 50, 255, cv2.THRESH_BINARY_INV)
plt.imshow(mask, cmap='gray');

# %%
mask_inv = cv2.bitwise_not(mask)
plt.imshow(mask_inv, cmap='gray');

# %%
img_bg = cv2.bitwise_and(roi, roi, mask=mask)
plt.imshow(img_bg[:,:,::-1]);

# %%
img_fg = cv2.bitwise_and(logo, logo, mask=mask_inv)
plt.imshow(img_fg[:,:,::-1]);

# %%
dst = cv2.add(img_bg, img_fg)
plt.imshow(dst[:,:,::-1]);

# %%
out = img.copy()
out[0:rows, 0:cols] = dst
plt.imshow(out[:,:,::-1]);
